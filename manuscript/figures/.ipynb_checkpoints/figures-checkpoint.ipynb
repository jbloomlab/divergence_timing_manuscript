# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Figures-for-divergence-timing-manuscript." data-toc-modified-id="Figures-for-divergence-timing-manuscript.-1">Figures for divergence timing manuscript.</a></span><ul class="toc-item"><li><span><a href="#Notebook-Setup" data-toc-modified-id="Notebook-Setup-1.1">Notebook Setup</a></span><ul class="toc-item"><li><span><a href="#Load-packages" data-toc-modified-id="Load-packages-1.1.1">Load packages</a></span></li><li><span><a href="#Colors" data-toc-modified-id="Colors-1.1.2">Colors</a></span></li></ul></li><li><span><a href="#Substitution-model-comparison" data-toc-modified-id="Substitution-model-comparison-1.2">Substitution model comparison</a></span><ul class="toc-item"><li><span><a href="#Stationary-states" data-toc-modified-id="Stationary-states-1.2.1">Stationary states</a></span></li><li><span><a href="#$\Gamma$-distribution-plot" data-toc-modified-id="$\Gamma$-distribution-plot-1.2.2">$\Gamma$-distribution plot</a></span></li></ul></li><li><span><a href="#Decay-to-stationary-state" data-toc-modified-id="Decay-to-stationary-state-1.3">Decay to stationary state</a></span></li><li><span><a href="#Simulations" data-toc-modified-id="Simulations-1.4">Simulations</a></span></li><li><span><a href="#Empirical-Data" data-toc-modified-id="Empirical-Data-1.5">Empirical Data</a></span><ul class="toc-item"><li><span><a href="#Prefs-snippet" data-toc-modified-id="Prefs-snippet-1.5.1">Prefs snippet</a></span></li><li><span><a href="#Trees" data-toc-modified-id="Trees-1.5.2">Trees</a></span><ul class="toc-item"><li><span><a href="#H1-Trees" data-toc-modified-id="H1-Trees-1.5.2.1">H1 Trees</a></span></li><li><span><a href="#H3-trees" data-toc-modified-id="H3-trees-1.5.2.2">H3 trees</a></span></li><li><span><a href="#Average-Trees" data-toc-modified-id="Average-Trees-1.5.2.3">Average Trees</a></span></li></ul></li><li><span><a href="#All-together" data-toc-modified-id="All-together-1.5.3">All together</a></span></li><li><span><a href="#Take-two?" data-toc-modified-id="Take-two?-1.5.4">Take two?</a></span></li><li><span><a href="#Take-three?" data-toc-modified-id="Take-three?-1.5.5">Take three?</a></span></li></ul></li><li><span><a href="#Shifting-Preferences-vs.-Long-Branches" data-toc-modified-id="Shifting-Preferences-vs.-Long-Branches-1.6">Shifting Preferences vs. Long Branches</a></span><ul class="toc-item"><li><span><a href="#Doud-Experiment" data-toc-modified-id="Doud-Experiment-1.6.1">Doud Experiment</a></span><ul class="toc-item"><li><span><a href="#Tree" data-toc-modified-id="Tree-1.6.1.1">Tree</a></span></li><li><span><a href="#$\beta$-decay" data-toc-modified-id="$\beta$-decay-1.6.1.2">$\beta$ decay</a></span></li><li><span><a href="#Scatterplot" data-toc-modified-id="Scatterplot-1.6.1.3">Scatterplot</a></span></li><li><span><a href="#All-together" data-toc-modified-id="All-together-1.6.1.4">All together</a></span></li></ul></li><li><span><a href="#Lee-Experiment" data-toc-modified-id="Lee-Experiment-1.6.2">Lee Experiment</a></span><ul class="toc-item"><li><span><a href="#Tree" data-toc-modified-id="Tree-1.6.2.1">Tree</a></span></li><li><span><a href="#$\beta$-decay" data-toc-modified-id="$\beta$-decay-1.6.2.2">$\beta$ decay</a></span></li><li><span><a href="#Scatterplot" data-toc-modified-id="Scatterplot-1.6.2.3">Scatterplot</a></span></li></ul></li></ul></li><li><span><a href="#Logoplots" data-toc-modified-id="Logoplots-1.7">Logoplots</a></span><ul class="toc-item"><li><span><a href="#Doud-logoplots" data-toc-modified-id="Doud-logoplots-1.7.1">Doud logoplots</a></span></li><li><span><a href="#Lee-logoplots" data-toc-modified-id="Lee-logoplots-1.7.2">Lee logoplots</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Figures for divergence timing manuscript.
#
# Below is the code to generate the un-edited versions of the figures for the divergence timing manuscript.
# The final verisons can be found in `figures.pptx`.

# %% [markdown]
# ## Notebook Setup

# %% [markdown]
# ### Load packages
#
# Here are the packages I used to create the figures and their associated references:
#
# 1. [`ggplot2`](https://cran.r-project.org/web/packages/ggplot2/citation.html)
# 2. [`cowplot`](https://github.com/wilkelab/cowplot)
# 3. [`ggseqlogo`](https://github.com/omarwagih/ggseqlogo)
# 4. [`ggtree`](https://bioconductor.org/packages/release/bioc/html/ggtree.html)

# %%
library(ggplot2)
library(cowplot)
require(ggseqlogo)
library(ggtree)
library(grid)
library(gridExtra)
library(dplyr)
# Out:
# Attaching package: ‘cowplot’
#
# The following object is masked from ‘package:ggplot2’:
#
#     ggsave
#
# Loading required package: ggseqlogo
# Loading required package: treeio
# ggtree v1.8.2  For help: https://guangchuangyu.github.io/ggtree
#
# If you use ggtree in published research, please cite:
# Guangchuang Yu, David Smith, Huachen Zhu, Yi Guan, Tommy Tsan-Yuk Lam. ggtree: an R package for visualization and annotation of phylogenetic trees with their covariates and other associated data. Methods in Ecology and Evolution 2017, 8(1):28-36, doi:10.1111/2041-210X.12628
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:gridExtra’:
#
#     combine
#
# The following object is masked from ‘package:ggtree’:
#
#     collapse
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# ### Colors

# %%
black = "black"
blue = "#439FC3"
green = "#76A88D"
orange = "#F9842A"
red = "#B52A24"
pink = "#CC79A7"
purple = "#8E7790"

# %% [markdown]
# ## Substitution model comparison
#
# Below is the code to make figure to compare the different substitution models. This figure has three pieces:
#
# 1. Short stretches of logoplot to compare stationary states
# 2. Plot of $\Gamma$-distribution for rate variation
# 3. Feature comparison for the four models in the paper (added in powerpoint)

# %% [markdown]
# ### Stationary states
#
# This part of the plot will show small stretches of the stationary state from a `YNGKP M0` model and an `ExpCM`.
# The stationary states were made using a script found in `decay_to_stationary`.

# %%
prefs_to_matrix <- function(fname) {
  df = read.csv(fname)
  rownames(df) = df$site
  df <- subset(df, select = -c(site) )
  df <- t(df)
  return(df)
}

small_color = '#f76ab4'
nucleophilic_color = '#ff7f00'
hydrophobic_color = '#12ab0d'
aromatic_color = '#84380b'
acidic_color = '#3c58e5'
amide_color = '#972aa8'
basic_color = '#e41a1c'
functionalGroup = make_col_scheme(chars=c('G', 'A', 'S', 'T', 'C', 'V', 'L', 'I', 'M', 'P', 'F', 'Y', 'W', 'D', 'E', 'H', 'K', 'R', 'N', 'Q'), 
                                  cols=c(small_color, small_color, nucleophilic_color, nucleophilic_color, nucleophilic_color, hydrophobic_color,hydrophobic_color,hydrophobic_color,hydrophobic_color,hydrophobic_color, aromatic_color,aromatic_color,aromatic_color, acidic_color, acidic_color, basic_color, basic_color, basic_color,amide_color,amide_color))

# %%
targets = c(90,51,481,490,23,395,81)
l = 
l = list(YNGKP=prefs_to_matrix("../../analysis/decay_to_stationary/outputs/YNGKP_M0_stationarystate.csv"), ExpCM=prefs_to_matrix("../../analysis/decay_to_stationary/outputs/ExpCM_stationarystate.csv")) 
ss <- ggplot() + geom_logo(l, method="prob",col_scheme=functionalGroup) + theme_logo(base_size = 30) 
ss <-  ss + facet_wrap(~seq_group, ncol=2, scales='free_x') 
ss <- ss + theme(axis.text.y=element_blank(), axis.title.y=element_blank(), axis.text.x=element_blank()) # remove y-axis text.
ss
ggsave("_raw_ss.png", width=10)
# Out:
# Saving 10 x 7 in image
# plot without title

# %% [markdown]
# ### $\Gamma$-distribution plot
#
# This plot shows the 4 $\omega$ values from a YNGKP M5 and the 1 $\omega$ value from a YNGKP M0.
# The values are found in the file `wr.csv` in the `decay_to_stationary/outputs/`

# %%
# read in the dataframe from decay to stationary 
model_params = read.csv("../../analysis/decay_to_stationary/outputs/wr.csv")
# get the gamma distribution
gamma = subset(model_params, type == "gamma")
alpha_omega = subset(gamma, model=="alpha_omega")$omega[[1]]
beta_omega = subset(gamma, model=="beta_omega")$omega[[1]]
x <- seq(-.1,1.1,length=100)
y <- dgamma(x, alpha_omega, beta_omega)
df <- data.frame(x,y)
# get the omega values
means = subset(model_params, type == "omega")
means$y_axis = append(rep(0, (nrow(means)-1)), 0.75) 

myColors <- c(orange, blue)
colorScale <- scale_color_manual(name = "Model", values = myColors)

omega <- ggplot(df, aes(x,y)) + geom_line(color=blue) 
omega <- omega + xlab("omega value") + theme(axis.text.x = element_text(size=25),axis.line.y = element_blank(), axis.ticks.y = element_blank(), axis.text.y = element_blank(), axis.title.y=element_blank(), legend.position = "none")
omega <- omega + colorScale + xlim(c(-.01, 0.6))
omega <- omega + geom_point(data=means, aes(omega,y_axis, color=model), size = 7)
omega
ggsave("_raw_omega.png")
# Out:
# Warning message:
# “Removed 50 rows containing missing values (geom_path).”
# Saving 7 x 7 in image
# Warning message:
# “Removed 50 rows containing missing values (geom_path).”
# plot without title

# %% [markdown]
# ## Decay to stationary state
#
# This plot shows the decay to stationary state for 4 different models:
#
# 1. GY94 (YNGKP M0)
# 2. GY94 + $\Gamma\omega$ (YNGKP M5)
# 3. GY94 + $\omega_r$
# 4. ExpCM
#
# I picked 5 sites to represent different behaviors of the model.

# %%
df = read.csv("../../analysis/decay_to_stationary/outputs/expected_identity_given_time_t.csv")
targets = c(90,51,413,300,262) # sites to include in the plot
time = 30 # width of the x-axis 
df = df[is.element(df$Site, targets),]

myColors <- c(red, orange, blue, green)
fillScale <- scale_fill_manual(name = "Model", values = myColors)
colorScale <- scale_color_manual(name = "Model", values = myColors)

df$Site_f = factor(df$Site, levels=targets)
df$Model = factor(df$Model, levels = c("ExpCM", "GY94 + wr", "GY94", "GY94 + Gr"))

df <- df[which(df[,3]<=time),]

p <- ggplot(df, aes(Time,f,color=Model)) + geom_line(size=1.0) + ylim(0,1.0) 
p <- p + facet_grid(~Site_f) + geom_hline(yintercept = 0.05, color = "darkgrey", linetype = "dotted")
p <- p + theme(strip.background = element_blank(), legend.position = "bottom", legend.title= element_text(face="bold"), axis.text = element_text(size=12))
p <- p + xlab("Branch length \n(average number of codon substitutions per site)") + ylab("Expected pairwise amino-acid identity at site")
p <- p + colorScale + guides(colour = guide_legend(override.aes = list(size=5)))
ggdraw(p) + draw_label("Residue in WSN", x = 0.15, y = 0.97, vjust = 1, hjust = 1, size = 10)
ggsave("_raw_decay.png", width=9, height=5)

wr = read.csv("../../analysis/decay_to_stationary/outputs/spielman_wr.csv")
wr = wr[is.element(wr$site, targets),]
print(wr)
# Out:
#     site         wr
# 51    51 0.16694007
# 90    90 0.18057422
# 262  262 0.02655474
# 300  300 0.05701922
# 413  413 0.09987039
# plot without title

# %% [markdown]
# ## Simulations
#
# Below is the code to plot the inferred distance vs. true distance for different mdoels.

# %%
df = read.csv("../../analysis/simulations/outputs/model_by_model.csv")
df$model_pair = factor(df$model_pair, levels = c("true/GY94",
                                                 "true/GY94_gammaomega", 
                                                 "true/ExpCM_averaged",
                                                 "true/ExpCM_gammaomega_averaged",
                                                 "true/ExpCM",
                                                 "true/ExpCM_gammaomega"))
means = read.csv("../../analysis/simulations/outputs/model_by_model_means.csv")

# %%
m <- ceiling(max(max(df$distance1), max(df$distance2)))
scatter = ggplot(df, aes(distance1, distance2)) + geom_abline(intercept=0, slope=1, color = "darkgrey", linetype="dashed") + geom_point(size=1.0, color="grey") 
scatter = scatter + facet_grid(~model_pair)
scatter = scatter + theme_bw()+ theme(panel.grid.major = element_blank(),
                    panel.grid.minor = element_blank(),
                    strip.background = element_blank(),
                    panel.border = element_rect(colour = "black"), 
                    strip.text = element_text(size=6),
                    axis.text = element_text(size=13))
scatter = scatter + xlim(c(0,m)) + ylim(c(0,m)) + coord_fixed() 
scatter = scatter + xlab("model") + ylab("true") + geom_point(size = 0.5, data = means)
scatter
ggsave("raw_simulations.png", width=12)
# Out:
# Saving 12 x 7 in image
# plot without title

# %% [markdown]
# ## Empirical Data
#
# Below is the code to look at the trees optimized using different ExpCM models. The figure has four parts
#
# 1. Preference snippets for H1, H3, and average prefs
# 2. Trees aligned to WSN
# 3. Trees aligned to Perth
# 4. Trees aligned to the hybrid sequence
#
# The trees are made using the R package [`ggtree`](https://bioconductor.org/packages/release/bioc/html/ggtree.html)

# %% [markdown]
# ### Prefs snippet

# %%
prefs_to_matrix <- function(df, beta) {
  rownames(df) = df$site
  df <- subset(df, select = -c(site) )
  df <- t(df) ^ beta
  return(df)
}

start = 290
stop = 310
map = read.csv("../../analysis/HA/data/references/hybrid_numbering.csv")
map = map[map$hybrid>start & map$hybrid<stop, ]

# subset prefs
doud_prefs = read.csv("../../analysis/HA/data/references/HA_Doud_prefs.csv") %>% filter(site %in% map$WSN)
lee_prefs = read.csv("../../analysis/HA/data/references/HA_Lee_prefs.csv") %>% filter(site %in% map$Perth)
average_prefs = read.csv("../../analysis/HA/data/references/HA_average_prefs.csv") %>% filter(site %in% map$hybrid)

# make logoplots
l = list(H1=prefs_to_matrix(doud_prefs, 1.54), Average=prefs_to_matrix(average_prefs, 1.77), H3=prefs_to_matrix(lee_prefs, 1.76)) 
prefs <- ggplot() + geom_logo(l, method="prob",col_scheme=functionalGroup) + theme_logo(base_size = 30) 
prefs <-  prefs + facet_wrap(~seq_group, ncol=1, scales='free_x') 
prefs <- prefs + theme(axis.text.y=element_blank(), axis.title.y=element_blank(), axis.text.x=element_blank(), strip.text=element_blank()) # remove y-axis text.
prefs
ggsave("_raw_prefs.png")
# Out:
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# ### Trees

# %%
# General Tree                           
make_tree <- function(fname, name, limit, c){
  tree <- read.tree(fname) 
  p <- ggtree(tree, color = c, size=.75) + ggtitle(name) + theme_tree2() + scale_x_continuous(limits = c(0, limit)) 
}

# %% [markdown]
# #### H1 Trees
#
# Here are the trees aligned to WSN and optimized with an ExpCM built on Mike's preferences.

# %%
max_distance <- 18
YNGKP_M0 <- make_tree("../../analysis/HA/branch_lengths/phydms/WSN_high_0_YNGKP_M0_tree.newick", "GY94", max_distance, blue)
ExpCM <- make_tree("../../analysis/HA/branch_lengths/phydms/WSN_high_0_ExpCM_HA_Doud_prefs_tree.newick", "ExpCM", max_distance, blue)
YNGKP_M5 <- make_tree("../../analysis/HA/branch_lengths/phydms/WSN_high_0_YNGKP_M5_tree.newick", "GY94 + G", max_distance, blue)
ExpCM_gammaomega <- make_tree("../../analysis/HA/branch_lengths/phydms/WSN_high_0_ExpCM_HA_Doud_prefs_gammaomega_tree.newick", "ExpCM + G", max_distance, blue)

g <- arrangeGrob(YNGKP_M0, YNGKP_M5, ExpCM, ExpCM_gammaomega, ncol=2) #generates g
doud_tree <- plot_grid(g)
doud_tree
ggsave("_raw_doud_tree.png")
# Out:
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# #### H3 trees
#
# Here the trees are aligned to Perth and optimized with an ExpCM model built with Juhye's preferences

# %%
max_distance <- 18
YNGKP_M0 <- make_tree("../../analysis/HA/branch_lengths/phydms/Perth_high_0_YNGKP_M0_tree.newick", "GY94", max_distance, orange)
ExpCM <- make_tree("../../analysis/HA/branch_lengths/phydms/Perth_high_0_ExpCM_HA_Lee_prefs_tree.newick", "ExpCM", max_distance, orange)
YNGKP_M5 <- make_tree("../../analysis/HA/branch_lengths/phydms/Perth_high_0_YNGKP_M5_tree.newick", "GY94 + G", max_distance, orange)
ExpCM_gammaomega <- make_tree("../../analysis/HA/branch_lengths/phydms/Perth_high_0_ExpCM_HA_Lee_prefs_gammaomega_tree.newick", "ExpCM + G", max_distance, orange)

g <- arrangeGrob(YNGKP_M0, YNGKP_M5, ExpCM, ExpCM_gammaomega, ncol=2) #generates g
lee_tree <- plot_grid(g)
lee_tree
ggsave("_raw_lee_tree.png")
# Out:
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# #### Average Trees
#
# These trees are aligned to the hybrid sequence and optimized using an ExpCM built with the *average* of Mike and Juhye's preferences

# %%
max_distance <- 18
YNGKP_M0 <- make_tree("../../analysis/HA/branch_lengths/phydms/hybrid_high_0_YNGKP_M0_tree.newick", "GY94", max_distance, green)
ExpCM <- make_tree("../../analysis/HA/branch_lengths/phydms/hybrid_high_0_ExpCM_HA_average_prefs_tree.newick", "ExpCM", max_distance, green)
YNGKP_M5 <- make_tree("../../analysis/HA/branch_lengths/phydms/hybrid_high_0_YNGKP_M5_tree.newick", "GY94 + G", max_distance, green)
ExpCM_gammaomega <- make_tree("../../analysis/HA/branch_lengths/phydms/hybrid_high_0_ExpCM_HA_average_prefs_gammaomega_tree.newick", "ExpCM + G", max_distance, green)

g <- arrangeGrob(YNGKP_M0, YNGKP_M5, ExpCM, ExpCM_gammaomega, ncol=2) #generates g
average_tree <- plot_grid(g)
average_tree
ggsave("_raw_average_tree.png")
# Out:
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# ### All together

# %%
empirical_data = plot_grid(prefs, doud_tree, lee_tree, average_tree)
empirical_data
# Out:
# plot without title

# %% [markdown]
# ### Take two?

# %%
max_distance <- 18
YNGKP_M0 <- make_tree("../../analysis/HA/branch_lengths/phydms/hybrid_high_0_YNGKP_M0_tree.newick", "GY94", max_distance, black)
YNGKP_M5 <- make_tree("../../analysis/HA/branch_lengths/phydms/hybrid_high_0_YNGKP_M5_tree.newick", "GY94 + G", max_distance, black)

ExpCM_doud <- make_tree("../../analysis/HA/branch_lengths/phydms/WSN_high_0_ExpCM_HA_Doud_prefs_tree.newick", "ExpCM (Doud)", max_distance, blue)
ExpCM_average <- make_tree("../../analysis/HA/branch_lengths/phydms/hybrid_high_0_ExpCM_HA_average_prefs_tree.newick", "ExpCM (average)", max_distance, green)
ExpCM_lee <- make_tree("../../analysis/HA/branch_lengths/phydms/Perth_high_0_ExpCM_HA_Lee_prefs_tree.newick", "ExpCM (Lee)", max_distance, orange)

ExpCM_doud_gammaomega <- make_tree("../../analysis/HA/branch_lengths/phydms/WSN_high_0_ExpCM_HA_Doud_prefs_gammaomega_tree.newick", "ExpCM + G (Doud)", max_distance, blue)
ExpCM_average_gammaomega <- make_tree("../../analysis/HA/branch_lengths/phydms/hybrid_high_0_ExpCM_HA_average_prefs_gammaomega_tree.newick", "ExpCM + G (average)", max_distance, green)
ExpCM_lee_gammaomega <- make_tree("../../analysis/HA/branch_lengths/phydms/Perth_high_0_ExpCM_HA_Lee_prefs_gammaomega_tree.newick", "ExpCM + G (Lee)", max_distance, orange)


g <- arrangeGrob(YNGKP_M0, YNGKP_M5, ExpCM_doud, ExpCM_doud_gammaomega ,ExpCM_lee, ExpCM_lee_gammaomega, ExpCM_average, ExpCM_average_gammaomega, ncol=2) #generates g
t <- plot_grid(g)
t
ggsave("_alt_raw_trees.png")
# Out:
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# ### Take three?

# %%
max_distance <- 18
YNGKP_M0 <- make_tree("../../analysis/HA/branch_lengths/phydms/hybrid_high_0_YNGKP_M0_tree.newick", "GY94", max_distance, black)
YNGKP_M5 <- make_tree("../../analysis/HA/branch_lengths/phydms/hybrid_high_0_YNGKP_M5_tree.newick", "GY94 + G", max_distance, black)

ExpCM_doud <- make_tree("../../analysis/HA/branch_lengths/phydms/WSN_high_0_ExpCM_HA_Doud_prefs_tree.newick", "ExpCM (Doud)", max_distance, blue)
ExpCM_average <- make_tree("../../analysis/HA/branch_lengths/phydms/hybrid_high_0_ExpCM_HA_average_prefs_tree.newick", "ExpCM (average)", max_distance, green)
ExpCM_lee <- make_tree("../../analysis/HA/branch_lengths/phydms/Perth_high_0_ExpCM_HA_Lee_prefs_tree.newick", "ExpCM (Lee)", max_distance, orange)

ExpCM_doud_gammaomega <- make_tree("../../analysis/HA/branch_lengths/phydms/WSN_high_0_ExpCM_HA_Doud_prefs_gammaomega_tree.newick", "ExpCM + G (Doud)", max_distance, blue)
ExpCM_average_gammaomega <- make_tree("../../analysis/HA/branch_lengths/phydms/hybrid_high_0_ExpCM_HA_average_prefs_gammaomega_tree.newick", "ExpCM + G (average)", max_distance, green)
ExpCM_lee_gammaomega <- make_tree("../../analysis/HA/branch_lengths/phydms/Perth_high_0_ExpCM_HA_Lee_prefs_gammaomega_tree.newick", "ExpCM + G (Lee)", max_distance, orange)

# prefs
prefs_to_matrix <- function(df, beta) {
  rownames(df) = df$site
  df <- subset(df, select = -c(site) )
  df <- t(df) ^ beta
  return(df)
}

make_prefs_plot <- function(l){
  prefs <- ggplot() + geom_logo(l, method="prob",col_scheme=functionalGroup) + theme_logo(base_size = 30) 
    prefs <-  prefs + facet_wrap(~seq_group, ncol=1, scales='free_x') 
    prefs <- prefs + theme(axis.text.y=element_blank(), axis.title.y=element_blank(), axis.text.x=element_blank(), strip.text=element_blank()) # remove y-axis text.
    return(prefs)  
}

start = 290
stop = 310
map = read.csv("../../analysis/HA/data/references/hybrid_numbering.csv")
map = map[map$hybrid>start & map$hybrid<stop, ]

# subset prefs
doud_prefs = read.csv("../../analysis/HA/data/references/HA_Doud_prefs.csv") %>% filter(site %in% map$WSN)
lee_prefs = read.csv("../../analysis/HA/data/references/HA_Lee_prefs.csv") %>% filter(site %in% map$Perth)
average_prefs = read.csv("../../analysis/HA/data/references/HA_average_prefs.csv") %>% filter(site %in% map$hybrid)
GY_prefs = read.csv("../../analysis/decay_to_stationary/outputs/YNGKP_M0_stationarystate.csv")
GY_prefs =GY_prefs[1,]
GY_prefs = GY_prefs[rep(row.names(GY_prefs), stop-start-1),]
GY_prefs$site = map$hybrid

#make logoplots
prefs_doud = make_prefs_plot(list(H1=prefs_to_matrix(doud_prefs, 1.54)))
prefs_average = make_prefs_plot(list(Average=prefs_to_matrix(average_prefs, 1.77)))
prefs_lee = make_prefs_plot(list(H3=prefs_to_matrix(lee_prefs, 1.76)))
prefs_gy = make_prefs_plot(list(GY=prefs_to_matrix(GY_prefs, 1.0)))

# put it all together 
GY = arrangeGrob(YNGKP_M0, YNGKP_M5, ncol=2)
tree_doud = arrangeGrob(ExpCM_doud, ExpCM_doud_gammaomega, ncol=2)
tree_lee = arrangeGrob(ExpCM_lee, ExpCM_lee_gammaomega, ncol=2)
tree_average = arrangeGrob(ExpCM_average, ExpCM_average_gammaomega, ncol=2)
p = plot_grid(prefs_gy, GY, prefs_doud, tree_doud, prefs_lee, tree_lee, prefs_average, tree_average, ncol=2)
p
ggsave("_alt2_raw_trees.png")
# Out:
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# ## Shifting Preferences vs. Long Branches
#
# The figure should put together all of the data from one "experiment."
# This includes
#
# 1. The final tree with the different alignment annotated.
# 2. The $\beta$ decay
# 3. The branch length comparison scatterplots.

# %% [markdown]
# ### Doud Experiment
#
# Below is the data for the trees aligned to WSN and optimized with an ExpCM built on Mike's preferences.

# %% [markdown]
# #### Tree
#
# The code below is just copied and pasted from the "Trees" section of this notebook.

# %%
doud_tree <- make_tree("../../analysis/HA/branch_lengths/phydms/WSN_high_0_YNGKP_M0_tree.newick", "", 8, blue)
ggsave("_raw_doud_tree_one.png")
# Out:
# Saving 7 x 7 in image

# %% [markdown]
# #### $\beta$ decay
#
# This plot shows how the $\beta$ value decreases as the max divergence of the alignment increases.
#
# *Note: In order to get the presentation ready for Trevor, I copied over old data*

# %%
beta = read.csv("../../analysis/HA/branch_lengths/outputs/params.csv")%>% filter(param == "beta"& alignment_ref == "WSN")
beta$divergence_level = factor(beta$divergence_level, levels = c("low", "intermediate", "high"))
doud_beta = ggplot(beta, aes(divergence_level, value, shape=model)) + geom_point(size=4) 
doud_beta = doud_beta + geom_hline(yintercept=1, linetype="dashed", color="lightgrey")
doud_beta = doud_beta + theme(legend.position="None")
doud_beta
# ggsave("raw_doud_beta.png")
# Out:
# plot without title

# %% [markdown]
# #### Scatterplot
#
# This scatterplot compares the branch lengths optimized under different models.
#
# *Note: To make my meeting with Trevor this is made with data copied over from another experiment*

# %%
doud = read.csv("../../analysis/HA/branch_lengths/outputs/model_by_model.csv") %>% filter(alignment_ref == "WSN" & bootstrap == "phydms")

# %%
m <- ceiling(max(max(doud$distance1), max(doud$distance2)))
doud_branch_lengths = ggplot(doud, aes(distance1, distance2)) + geom_abline(intercept=0, slope=1, color = "grey", linetype="dashed") + geom_point(size=1.0, color="grey") 
doud_branch_lengths = doud_branch_lengths + facet_grid(divergence_level~ model_pair)
doud_branch_lengths = doud_branch_lengths + theme(strip.background = element_blank(), strip.text = element_text(size=8), legend.position="bottom", panel.spacing = unit(2, "lines"), panel.border = element_rect(colour = "black"))
doud_branch_lengths = doud_branch_lengths + xlim(c(0,m)) + ylim(c(0,m)) + coord_fixed() 
doud_branch_lengths = doud_branch_lengths + xlab("model 1") + ylab("model 2") + geom_point(size = 0.5, data = subset(doud, from_ref == 'WSN'), color=blue)
doud_branch_lengths
# ggsave("raw_doud_branch_lengths.png")
# # ggsave("outputs/figures/experiment_doud_scatter.png")
# Out:
# plot without title

# %% [markdown]
# #### All together

# %%
top_row = plot_grid(doud_tree, doud_beta,rel_widths = c(1.3, 1))
plot_grid(top_row, doud_branch_lengths, ncol=1, rel_heights=c(1, 1.3))
ggsave("_raw_doud_competing.png")
# Out:
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# ### Lee Experiment
#
# Below is the data for the trees aligned to Perth and optimized with an ExpCM built on Juhye's preferences.

# %% [markdown]
# #### Tree
#
# This code is just copied from the code in the "Trees" section.

# %%
lee_tree <- make_tree("../../analysis/HA/branch_lengths/phydms/Perth_high_0_YNGKP_M0_tree_norm.newick", "", 13, orange)
lee_tree + xlab("Normalized branch length")
ggsave("raw_lee_tree_one.png")
# Out:
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# #### $\beta$ decay
#
# This plot shows how the $\beta$ value decreases as the max divergence of the alignment increases.
#
# *Note: In order to get the presentation ready for Trevor, I copied over old data*

# %%
beta = read.csv("_temp_modelparams_lee.csv")
beta = subset(beta, param == "beta")
beta$alignment = factor(beta$alignment, levels = c("HA_greater_75", "HA_greater_60", "HA_greater_0"))

lee_beta = ggplot(beta, aes(alignment, value, shape=clean_model)) + geom_point(size=4) 
lee_beta = lee_beta + geom_hline(yintercept=1, linetype="dashed", color="lightgrey")
lee_beta = lee_beta + theme(legend.position="bottom")
lee_beta
ggsave("raw_lee_beta.png")
# Out:
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# #### Scatterplot
#
# This scatterplot compares the branch lengths optimized under different models.
#
# *Note: To make my meeting with Trevor this is made with data copied over from another experiment*

# %%
lee = read.csv("_temp_mode_by_model_lee.csv")
head(lee)

scatter_colors <- c("grey",orange)
scatter_colors_scale <- scale_color_manual(name = "Reference sequence", values = scatter_colors)

m <- ceiling(max(max(lee$distance1), max(lee$distance2)))
lee_branch_lengths = ggplot(lee, aes(distance1, distance2, color=FromRef)) + geom_abline(intercept=0, slope=1, color = "grey", linetype="dashed") + geom_point(size=1.0) 
lee_branch_lengths = lee_branch_lengths + facet_grid(alignment~ model_pair)
lee_branch_lengths = lee_branch_lengths + theme(strip.background = element_blank(), strip.text = element_text(size=8), legend.position="bottom", panel.spacing = unit(2, "lines"), panel.border = element_rect(colour = "black"))
lee_branch_lengths = lee_branch_lengths + xlim(c(0,m)) + ylim(c(0,m)) + coord_fixed() 
lee_branch_lengths = lee_branch_lengths + xlab("model 1") + ylab("model 2") + scatter_colors_scale + geom_point(size = 0.5, data = subset(lee, FromRef == 'yes'))
lee_branch_lengths
ggsave("raw_lee_branch_lengths.png")
# Out:
#   FromRef HA_group alignment     distance1 distance2 model_pair
# 1 no      HA3_HA3  HA_greater_75 1.56945   1.44006   YNGKP_M5/YNGKP_M0
# 2 no      HA3_HA3  HA_greater_75 1.66026   1.52604   YNGKP_M5/YNGKP_M0
# 3 no      HA3_HA3  HA_greater_75 0.21721   0.21094   YNGKP_M5/YNGKP_M0
# 4 no      HA3_HA3  HA_greater_75 1.17392   1.08188   YNGKP_M5/YNGKP_M0
# 5 no      HA3_HA3  HA_greater_75 1.92486   1.77501   YNGKP_M5/YNGKP_M0
# 6 yes     HA3_HA3  HA_greater_75 1.89864   1.74911   YNGKP_M5/YNGKP_M0
#   seq_id
# 1 cds_AAA43164_A/equine/Miami/1963_1963//_HA_HA_3_cds_ABB04283_A/Hong_Kong/46/1980_1980//_HA_HA_3
# 2 cds_AAA43164_A/equine/Miami/1963_1963//_HA_HA_3_cds_ABD16571_A/Memphis/7/1990_1990//_HA_HA_3
# 3 cds_AAA43164_A/equine/Miami/1963_1963//_HA_HA_3_cds_ACD85176_A/equine/Kentucky/3/1986_1986//_HA_HA_3
# 4 cds_AAA43164_A/equine/Miami/1963_1963//_HA_HA_3_cds_AET75834_A/red_knot/Delaware_Bay/252/1994_1994/05/23_HA_HA_3
# ...

# %% [markdown]
# ## Logoplots
#
# Below is the code to make the logoplots representing the deep mutational scanning preferences from Mike's H1 WSN scan ([doud2016accurate](http://www.mdpi.com.offcampus.lib.washington.edu/1999-4915/8/6/155)) and Juhye's H3 Perth/09 scan ([lee2017Perth]()).
#
# The logoplots are created [`phydms_logoplot`](http://jbloomlab.github.io/phydms/phydms_logoplot.html).

# %% [markdown]
# ### Doud logoplots

# %%
cmd = "phydms_logoplot prefs_doud.pdf --prefs ../../analysis/HA/data/references/HA_Doud_prefs.csv --stringency 1.54 --nperline 113"
system(cmd, intern=TRUE)
# Out:
#  [1] ""
#  [2] "Beginning execution of phydms_logoplot in directory /Users/sarah/Google Drive/GS/lab/divergence_timing_manuscript/manuscript/figures at time Tue Jan 16 16:31:23 2018"
#  [3] ""
#  [4] "Version information:"
#  [5] "\tTime and date: Tue Jan 16 16:31:23 2018"
#  [6] "\tPlatform: Darwin-15.6.0-x86_64-i386-64bit"
#  [7] "\tPython version: 3.5.2 (v3.5.2:4def2a2901a5, Jun 26 2016, 10:47:25)  [GCC 4.2.1 (Apple Inc. build 5666) (dot 3)]"
#  [8] "\tphydms version: 2.2.0"
#  [9] "\tBio version: 1.68"
# [10] "\tcython version: 0.27.3"
# [11] "\tnumpy version: 1.13.3"
# [12] "\tscipy version: 0.19.0"
# [13] "\tmatplotlib version: 2.0.2"
# [14] "\tnatsort version: 5.1.1"
# [15] "\tsympy version: 1.0"
# [16] "\tsix version: 1.10.0"
# [17] "\tpandas version: 0.20.3"
# [18] "\tpyvolve version: 0.8.4"
# [19] "\tstatsmodels version: 0.8.0"
# [20] "\tweblogolib version: 3.5.0"
# [21] "\tPyPDF2 version: 1.26.0"
# [22] ""
# [23] "Parsed the following command-line arguments:"
# ...

# %% [markdown]
# ### Lee logoplots

# %%
cmd = "phydms_logoplot prefs_lee.pdf --prefs ../../analysis/HA/data/references/HA_Lee_prefs.csv --stringency 1.76 --nperline 113"
system(cmd, intern=TRUE)
# Out:
#  [1] ""
#  [2] "Beginning execution of phydms_logoplot in directory /Users/sarah/Google Drive/GS/lab/divergence_timing_manuscript/manuscript/figures at time Tue Jan 16 16:31:16 2018"
#  [3] ""
#  [4] "Version information:"
#  [5] "\tTime and date: Tue Jan 16 16:31:16 2018"
#  [6] "\tPlatform: Darwin-15.6.0-x86_64-i386-64bit"
#  [7] "\tPython version: 3.5.2 (v3.5.2:4def2a2901a5, Jun 26 2016, 10:47:25)  [GCC 4.2.1 (Apple Inc. build 5666) (dot 3)]"
#  [8] "\tphydms version: 2.2.0"
#  [9] "\tBio version: 1.68"
# [10] "\tcython version: 0.27.3"
# [11] "\tnumpy version: 1.13.3"
# [12] "\tscipy version: 0.19.0"
# [13] "\tmatplotlib version: 2.0.2"
# [14] "\tnatsort version: 5.1.1"
# [15] "\tsympy version: 1.0"
# [16] "\tsix version: 1.10.0"
# [17] "\tpandas version: 0.20.3"
# [18] "\tpyvolve version: 0.8.4"
# [19] "\tstatsmodels version: 0.8.0"
# [20] "\tweblogolib version: 3.5.0"
# [21] "\tPyPDF2 version: 1.26.0"
# [22] ""
# [23] "Parsed the following command-line arguments:"
# ...

# %%
cmd = "phydms_logoplot prefs_average.pdf --prefs ../../analysis/HA/data/references/HA_average_prefs.csv --stringency 1.77 --nperline 113"
system(cmd, intern=TRUE)
# Out:
#  [1] ""
#  [2] "Beginning execution of phydms_logoplot in directory /Users/sarah/Google Drive/GS/lab/divergence_timing_manuscript/manuscript/figures at time Tue Jan 16 16:31:09 2018"
#  [3] ""
#  [4] "Version information:"
#  [5] "\tTime and date: Tue Jan 16 16:31:09 2018"
#  [6] "\tPlatform: Darwin-15.6.0-x86_64-i386-64bit"
#  [7] "\tPython version: 3.5.2 (v3.5.2:4def2a2901a5, Jun 26 2016, 10:47:25)  [GCC 4.2.1 (Apple Inc. build 5666) (dot 3)]"
#  [8] "\tphydms version: 2.2.0"
#  [9] "\tBio version: 1.68"
# [10] "\tcython version: 0.27.3"
# [11] "\tnumpy version: 1.13.3"
# [12] "\tscipy version: 0.19.0"
# [13] "\tmatplotlib version: 2.0.2"
# [14] "\tnatsort version: 5.1.1"
# [15] "\tsympy version: 1.0"
# [16] "\tsix version: 1.10.0"
# [17] "\tpandas version: 0.20.3"
# [18] "\tpyvolve version: 0.8.4"
# [19] "\tstatsmodels version: 0.8.0"
# [20] "\tweblogolib version: 3.5.0"
# [21] "\tPyPDF2 version: 1.26.0"
# [22] ""
# [23] "Parsed the following command-line arguments:"
# ...
